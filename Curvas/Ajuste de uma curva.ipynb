# %%
######################################################################################################
# ALUNO : Luiz Felipe Dos Santos Alves
# MATRÍCULA : 2018094852
# TURMA : TF
######################################################################################################

# %%
#===================================================================
#                        IMPORTANTE
#  Por favor salvem o Jupyter Notebook como ATV01-FulanoDeTal.ipynb, 
#  onde FulanoDeTal é o seu nome completo e postem em nossa sala de
#  aula no MS Teams até 14:40hs !

# %%
# Atividade 1 - Ajuste de uma curva do tipo : y = a * sin(b*x + c)
# Usando curve_fit from Scipy, modifique os exemplos dados na aula anterior 
# para fazer o ajuste pedido
from scipy.optimize import curve_fit
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

def seno(x, a, b, c):
    return a*np.sin(b*x+c)

xxx = np.linspace(5,15)
yyy = seno(xxx,1,1,1)

ruido = 0.5*np.random.normal(size=yyy.size)
yyy = yyy + ruido

fig, ax = plt.subplots()
ax.scatter(xxx, yyy, s=20, color='#00b3b3', label='Data')

ax.set_yscale('linear')
ax.set_xscale('linear')
ax.set_ylim(-5,5)      
                           
pars, cov = curve_fit(f=seno,xdata=xxx,ydata=yyy,p0=[1,1,1], bounds=[-np.inf,np.inf])

res = (yyy - seno(xxx,*pars))*(yyy - seno(xxx,*pars))
aux = sum(res)
aux2 = np.sqrt(aux/(res.size))
ax.plot(xxx, seno(xxx, *pars), linestyle='--', linewidth=2, color='black')
print("A e B = ",*pars)
print ("Minimos Quadrados =",aux2)
# Out:
# A e B =  1.1656139920870772 0.9895530604652876 1.0371914852195254
# Minimos Quadrados = 0.4861005330988715

# %%
# Atividade 2 - Ajuste de uma curva do tipo : y = a/( (x - b)**2 + c )
# Usando curve_fit from Scipy, modifique os exemplos dados na aula anterior 
# para fazer o ajuste pedido
from scipy.optimize import curve_fit
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

def fun(x, a, b, c):
    return a/((x-b)**2+c)

xxx = np.linspace(-5,15)

yyy = fun(xxx,1,1,1)

ruido = 0.01*np.random.normal(size=yyy.size)
yyy = yyy + ruido

fig, ax = plt.subplots()
ax.scatter(xxx, yyy, s=20, color='#00b3b3', label='Data')


ax.set_yscale('linear')
ax.set_xscale('linear')
ax.set_ylim(-2,2)      
                           

pars, cov = curve_fit(f=fun,xdata=xxx,ydata=yyy,p0=[0,1,1], bounds=[-np.inf,np.inf])



res = (yyy - fun(xxx,*pars))*(yyy - fun(xxx,*pars))
aux = sum(res)
aux2 = np.sqrt(aux/(res.size))

ax.plot(xxx, fun(xxx, *pars), linestyle='--', linewidth=2, color='black')
print("A e B = ",*pars)
print ("Minimos Quadrados =",aux2)
# Out:
# A e B =  1.0008065009071778 0.9932806478965043 0.9933263776172042
# Minimos Quadrados = 0.009764929168725142

# %%
# Atividade 3 - Ajuste de uma curva do tipo : y = a* sin(b*x)*sqrt(x+c)
# Usando curve_fit from Scipy, modifique os exemplos dados na aula anterior 
# para fazer o ajuste pedido
from scipy.optimize import curve_fit
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

def fun1(x, a, b, c):
    return a* np.sin(b*x)* np.sqrt(x+c)

xxx = np.linspace(0,15)
yyy = fun1(xxx,1,1,1)

ruido = 0.5*np.random.normal(size=yyy.size)
yyy = yyy + ruido


fig, ax = plt.subplots()
ax.scatter(xxx, yyy, s=20, color='#00b3b3', label='Data')

ax.set_yscale('linear')
ax.set_xscale('linear')
ax.set_ylim(-2,2)      
                           
pars, cov = curve_fit(f=fun1,xdata=xxx,ydata=yyy,p0=[1,1,1], bounds=[-np.inf,np.inf])

res = (yyy - fun1(xxx,*pars))*(yyy - fun1(xxx,*pars))
aux = sum(res)
aux2 = np.sqrt(aux/(res.size))
 
ax.plot(xxx, fun1(xxx, *pars), linestyle='--', linewidth=2, color='black')
print("A e B = ",*pars)
print ("Minimos Quadrados =",aux2)
# Out:
# A e B =  0.9502256414774279 1.0017325830400845 1.5600749921793269
# Minimos Quadrados = 0.49133569052922343
